# %%
from reaxkit.io.fort73_handler import Fort73Handler
from reaxkit.analysis.fort73_analyzer import fort73_get

handler = Fort73Handler("fort.73")
df = fort73_get(handler)               # full table
df_subset = fort73_get(handler, ["iter", "Ebond", "Evdw"])
print(df.head())
print("-----------")
print(df_subset.head())
print(sum(df.iloc[5]))
# Out:
#    iter     Ebond    Eatom  Elp  Emol     Eval  Ecoa  Ehbo  Etors  Econj  \
# 0     0 -17648.27  2031.96 -0.0   0.0  2401.45   0.0   0.0    0.0    0.0
# 1     5 -17642.28  2028.28 -0.0   0.0  2399.58   0.0   0.0    0.0    0.0
# 2    10 -17636.28  2022.62 -0.0   0.0  2396.37   0.0   0.0    0.0    0.0
# 3    15 -17630.17  2014.96 -0.0   0.0  2391.90   0.0   0.0    0.0    0.0
# 4    20 -17622.74  2005.16 -0.0   0.0  2386.39   0.0   0.0    0.0    0.0
#
#       Evdw     Ecoul   Echarge  Efield  Eelect
# 0  3227.70 -15943.12  11390.41     0.0     0.0
# 1  3226.47 -15941.64  11389.10     0.0     0.0
# 2  3228.32 -15944.66  11391.72     0.0     0.0
# 3  3232.66 -15951.09  11397.32     0.0     0.0
# 4  3238.29 -15959.04  11404.25     0.0     0.0
# -----------
#    iter     Ebond     Evdw
# 0     0 -17648.27  3227.70
# 1     5 -17642.28  3226.47
# 2    10 -17636.28  3228.32
# 3    15 -17630.17  3232.66
# 4    20 -17622.74  3238.29
# -14526.4
