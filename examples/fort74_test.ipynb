# %%
from reaxkit.io.fort74_handler import Fort74Handler
from reaxkit.analysis import fort74_analyzer

h = Fort74Handler("fort.74")
df = h.dataframe()
print(df.shape)
print(df.head())

df2 = fort74_analyzer.get(h, sort="Emin", ascending=True)
print(df2.head())
# Out:
# (135, 6)
#   identifier     Emin  iter       Hf       V       D
# 0    bulk_c5 -180.170     0  221.861  26.731  16.180
# 1    bulk_c4 -180.570     0  221.461  27.060  15.984
# 2    bulk_c3 -180.886     0  221.144  27.391  15.790
# 3    bulk_c2 -181.122     0  220.909  27.725  15.600
# 4    bulk_c1 -181.278     0  220.752  28.062  15.413
#         identifier       Emin  iter       Hf         V      D
# 0    Zn_Pt111_hcp2 -10208.490     7  714.524  4157.623  6.259
# 1    Zn_Pt111_hcp1 -10208.420     7  714.594  4157.623  6.259
# 2  Zn_Pt111_bridge -10201.794    27  721.219  4157.623  6.259
# 3     Zn_Pt111_top -10161.443     8  761.571  4157.623  6.259
# 4       Pt111_slab -10107.817     0  548.713  4157.623  6.233
